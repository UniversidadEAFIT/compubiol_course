# %% [markdown]
# # TALLER 3 - INTRO PYTHON - AGOSTO 28

# %% [markdown]
# #Cuenta creada en DataCamp
# ![CUENTA%20DATACAMP.png](attachment:CUENTA%20DATACAMP.png)

# %% [markdown]
# #Niveles completos del curso Intro to Python for Data Science
# ![NIVELES%20CURSO%20COMPLETOS.png](attachment:NIVELES%20CURSO%20COMPLETOS.png)
# ![CURSO%20PYTHON%20COMPLETADO.png](attachment:CURSO%20PYTHON%20COMPLETADO.png)

# %% [markdown]
# #Ejercicios 1, 2 y 3 en Rosalind
# ![EJERCICIO%201%20ROSALIND.png](attachment:EJERCICIO%201%20ROSALIND.png)
# ![EJERCICIO%202%20ROSALIND.png](attachment:EJERCICIO%202%20ROSALIND.png)
# ![EJERCICIO%203%20ROSALIND.png](attachment:EJERCICIO%203%20ROSALIND.png)
# ![EJERCICIOS%20COMPLETADOS%20ROSALIND.png](attachment:EJERCICIOS%20COMPLETADOS%20ROSALIND.png)
