# %% [markdown]
# # Taller 3 - Python
# Kelly Castillo
#
# ### Datacamp

# %% [markdown]
# #### Suscripción a DataCamp

# %% [markdown]
# ![Py1.png.PNG](attachment:Py1.png.PNG)

# %% [markdown]
# #### Curso de Python Completado

# %% [markdown]
# ![Py2.png.png](attachment:Py2.png.png)

# %% [markdown]
# ### Rosalind

# %% [markdown]
# **Ejercicio 1**

# %% [markdown]
# ![InstallingPython.png.png](attachment:InstallingPython.png.png)

# %% [markdown]
# **Código**

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# **Ejercicio 2**

# %% [markdown]
# ![VariablesAndSomeArithmetic.png.PNG](attachment:VariablesAndSomeArithmetic.png.PNG)

# %% [markdown]
# **Código**

# %%
def hipotenusa(a,b):
    if(a > 1000 or b > 1000):
        print ("False")
    else:
        print (a**2 + b**2)

# %%
hipotenusa(806,803)
# Out:
# 1294445

# %% [markdown]
# **Ejericicio 3**

# %% [markdown]
# ![StringsAndLists.png.png](attachment:StringsAndLists.png.png)

# %% [markdown]
# **Código**

# %%
def palabras(a,b,c,d,s):
    print (s[a:b+1] + ' '+s[c:d+1])

# %%
palabras(52,63,152,161,"2ndLHuGiyApFMjIoPp5f7xmaA7OzTSWsuejm5aYDQ4pF3GJwqLo1PhysignathusRfbtL4O5cP7XPZTkrZ5SLkdEi4oauJz8D3pIv7FSvVxnxNDw7pCICdH57KCbW2rtTUEKxFEDi6zm5ACLEs8JYltOcarnivorusfwPlfeY3vT.")
# Out:
# Physignathus carnivorus
