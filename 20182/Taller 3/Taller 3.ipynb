# %% [markdown]
# # Taller 3: introducción a Python

# %% [markdown]
# Usuario de Data Camp:
# ![PerfilDataCamp.png](attachment:PerfilDataCamp.png)

# %% [markdown]
# Curso de Python realizado:
#
# ![CursoDataCamp1.jpg](attachment:CursoDataCamp1.jpg)
# ![CursoDataCamp2.jpg](attachment:CursoDataCamp2.jpg)

# %% [markdown]
# Ejercicios realizados de Rosalind:
#
# ![ProgresoRosalind1.jpg](attachment:ProgresoRosalind1.jpg)
# ![ProgresoRosalind2.jpg](attachment:ProgresoRosalind2.jpg)
# ![ProgresoRosalind.jpg](attachment:ProgresoRosalind.jpg)
