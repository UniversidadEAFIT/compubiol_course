# %% [markdown]
# ### Taller 1 Diana Jiménez

# %% [markdown]
# Hacer un Notebook en Jupyter con el registro de actividad. Tómele un pantallazo al usuario que creo y subalo al notebook (1 punto)

# %% [markdown]
# ![python1.png](attachment:python1.png)

# %% [markdown]
# Realizar 3 ejercicios de Rosalind y sibir el pantallazo de los tres ejercicios (1 Punto

# %% [markdown]
# ![ejercicio1.PNG](attachment:ejercicio1.PNG)

# %% [markdown]
# ![ejercicio2.PNG](attachment:ejercicio2.PNG)

# %% [markdown]
# ![ejercicio3.PNG](attachment:ejercicio3.PNG)

# %% [markdown]
# ![ejercicios.PNG](attachment:ejercicios.PNG)

# %% [markdown]
# Realizar un ejercicio de cada nivel de "Warmup-1 y Logic-1" de https://codingbat.com/python y subir el código en el notebook.

# %% [markdown]
# ![Captura%20de%20pantalla%20de%202019-02-22%2015-16-53%20%282%29.png](attachment:Captura%20de%20pantalla%20de%202019-02-22%2015-16-53%20%282%29.png)

# %% [markdown]
# ![Captura%20de%20pantalla%20de%202019-02-22%2015-11-07.png](attachment:Captura%20de%20pantalla%20de%202019-02-22%2015-11-07.png)

# %% [markdown]
# ![Captura%20de%20pantalla%20de%202019-02-22%2015-13-31.png](attachment:Captura%20de%20pantalla%20de%202019-02-22%2015-13-31.png)

# %% [markdown]
# ![list.png](attachment:list.png)
