# %% [markdown]
# # Taller 1. Esteban Garzón Franco
#
# - ## *Punto 2*
# ![Datacamp.png](attachment:Datacamp.png)

# %% [markdown]
# - ## *Punto 3*
#
# *2 ejercicios de String-1*
#
# *1. hello_name*
#
#
# - def hello_name(esteban):
#    - return "Hello " + esteban + "!";
#
# - *2. make_out_word*
#
#
# - def make_out_word(out, word):
#    - return out[0]+out[1]+word+out[2]+out[3];
#
# *2 ejercicios de List_1*
#
# *1. Sum3*
#
# - def sum3(nums):
#    - return nums[0] + nums[1] + nums[2]
#
#
# *2. Same_first_last*
# - def same_first_last(nums):
#    - return len(nums) >= 1 and nums[0] == nums[-1]

# %% [markdown]
# - ## *Punto 4*
# *3 ejercicios de Rosalind*
# *1. installing Python*
# ![ejercicio%20rosalind%201.jpg](attachment:ejercicio%20rosalind%201.jpg)
#
# *2. Variables and Some Arithmetic*
# ![ejercicio%20rosalind%202.jpg](attachment:ejercicio%20rosalind%202.jpg)
#
# *3. Strings and lists*
# ![ejercicio%20rosalind%203.jpg](attachment:ejercicio%20rosalind%203.jpg)

# %% [markdown]
# - ## *Punto 5*
#
# *1 ejercicio de Warmup-1*
#
# *monkey_trouble*
# - def monkey_trouble(a_smile, b_smile):
#    - if a_smile == b_smile: <br>
#         - return True <br>
#    - if a_smile != b_smile <br>
#         - return False <br>
#
# *1 ejercicio de Logic-1*
#
# - def caught_speeding(speed, is_birthday):
#     - if is birthday == True: <br>
#         -speed = speed - 5
#    - if speed <= 60: <br>
#         -return 0 <br>
#    - if speed > 60 and speed <=80: <br>
#         -return 1 <br>
#    - if speed >= 81: <br>
#         -return 2 <br>
