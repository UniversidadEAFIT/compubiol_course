# %% [markdown]
# Solución taller 1
#
# Profesor: Qué pasó con la primera parte del DataCamp?<br>
# Profesor: Cargaste las mismas imagenes para los puntos de 1 a 4<br>
#
# punto 1 & 2:
# ![image.png](attachment:image.png)
#
# Punto 3: dos ejercicios de "String-1" y "List-1".
# ![image.png](attachment:image.png)
#
#
# Punto 4: Rosalind
# ejercicio 1.
# ![image.png](attachment:image.png)
#
# ejercicio 2.
# ![image.png](attachment:image.png)
#
# ejercicio 3. este si me dio lidia
# ![image.png](attachment:image.png)
#
# Punto 5: el primer código es de logic y el segundo de warmup
#
# Profesor: Faltaron los otros dos ejercicios de List1, String1

# %%
def cigar_party(cigars, is_weekend):
    if 40<=cigars<=60 and not is_weekend:
        return True
    if 40<=cigars and is_weekend:
        return True
    else:
        return False
#ojo con la identación
print(cigar_party(30, False))
print(cigar_party(50, False))
print(cigar_party(70, 1))
# Out:
# False
# True
# True

# %%
def not_string(str):
    if len(str) >= 3 and str[:3] == "not":
        return str
    else:
        return "not " + str
  # str[:3] goes from the start of the string up to but not
  # including index 3
#ojo con la identación

# %%
not_string('not bad')
# Out:
# 'not bad'
