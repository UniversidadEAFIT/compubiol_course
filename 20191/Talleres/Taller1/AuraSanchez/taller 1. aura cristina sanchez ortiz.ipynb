# %% [markdown]
# # Taller 1. Aura Cristina Sanchez Ortiz
# - ## *Punto 2*
#
# ![Aura%20DataCamp.jpeg](attachment:Aura%20DataCamp.jpeg)

# %% [markdown]
# - ## *punto 3*
#
# *2 ejercicios de String-1*
# - *1. non_start*
#
#         def non_start(a, b):
#           return a[1:] + b[1:]
#
# - *2. first_half*
#
#        def first_half(str):
#         return str [:len(str)/2]
#
#  *2 ejercicios de List-1*
#
#  - *Sum2*
#
#
#     def sum2(nums):
#      if len(nums) == 0:
#          return 0
#      if len(nums) == 1:
#          return nums[0]
#      return nums[0] + nums[1]
#
#  - *Make_pi*
#
#        def make_pi():
#         return [3, 1, 4]

# %% [markdown]
# - ## *Punto 4*
#
# - *3 ejercicios de Rosalind*
#
# - *1. Installing Python*
# ![ejercicio%20rosalind%201%20Aura.jpg](attachment:ejercicio%20rosalind%201%20Aura.jpg)
#
# - *2. Variables and Some Arithmetic*
# ![ejercicio%20rosalind%202%20Aura.jpg](attachment:ejercicio%20rosalind%202%20Aura.jpg)
#
# - *3. Strings and Lists*
# ![ejercicio%20rosalind%203%20Aura.jpg](attachment:ejercicio%20rosalind%203%20Aura.jpg)

# %%
## *Punto 5*
##1 ejercicio de Warmup-1*

#monkey_trouble*

def monkey_trouble(a_smile, b_smile): 
    if a_smile == b_smile:
        return True 
    else: 
        return False 
            
##1 ejercicio de Logic-1*
#caught_speeding*

def caught_speeding(speed, is_birthday):
    if is_birthday == True: 
        speed = speed - 5
    if speed <= 60: 
        return 0 
    if speed > 60 and speed <=80: 
        return 1 
    if speed >= 81: 
        return 2

# %%
caught_speeding(65, False)
# Out:
# 1
