# %% [markdown]
# Taller 1 fundamentos de biología computacional.

# %% [markdown]
# 2)

# %% [markdown]
# ![Captura%20de%20pantalla%202019-02-23%20a%20la%28s%29%201.12.52%20p.m..png](attachment:Captura%20de%20pantalla%202019-02-23%20a%20la%28s%29%201.12.52%20p.m..png)

# %% [markdown]
# 3)

# %% [markdown]
# ![Captura%20de%20pantalla%202019-02-23%20a%20la%28s%29%201.38.39%20p.m..png](attachment:Captura%20de%20pantalla%202019-02-23%20a%20la%28s%29%201.38.39%20p.m..png)![Captura%20de%20pantalla%202019-02-23%20a%20la%28s%29%201.37.22%20p.m..png](attachment:Captura%20de%20pantalla%202019-02-23%20a%20la%28s%29%201.37.22%20p.m..png)

# %% [markdown]
# ![Captura%20de%20pantalla%202019-02-23%20a%20la%28s%29%201.41.41%20p.m..png](attachment:Captura%20de%20pantalla%202019-02-23%20a%20la%28s%29%201.41.41%20p.m..png)![Captura%20de%20pantalla%202019-02-23%20a%20la%28s%29%201.47.28%20p.m..png](attachment:Captura%20de%20pantalla%202019-02-23%20a%20la%28s%29%201.47.28%20p.m..png)

# %% [markdown]
# 4)![Captura%20de%20pantalla%202019-02-23%20a%20la%28s%29%202.00.17%20p.m..png](attachment:Captura%20de%20pantalla%202019-02-23%20a%20la%28s%29%202.00.17%20p.m..png)![Captura%20de%20pantalla%202019-02-23%20a%20la%28s%29%202.06.30%20p.m..png](attachment:Captura%20de%20pantalla%202019-02-23%20a%20la%28s%29%202.06.30%20p.m..png)![Captura%20de%20pantalla%202019-02-23%20a%20la%28s%29%203.10.36%20p.m..png](attachment:Captura%20de%20pantalla%202019-02-23%20a%20la%28s%29%203.10.36%20p.m..png)

# %% [markdown]
# 5)
# El problema es Sleep_in
# def sleep_in(weekday, vacation):
#   if (not weekday) or vacation:
#     return True
#   else:
#     return False

# %%
#El problema es Cigar_Party 

def cigar_party(cigars, is_weekend):
    if is_weekend:
        return cigars >= 40 
    else:
        return 40<= cigars <=60
    
cigar_party(70, 1)
# Out:
# True
