# %% [markdown]
# Actividad Data Camp ![Data_learning.JPG](attachment:Data_learning.JPG)

# %% [markdown]
# 2)Ejercicios Rosalind
# 1.![Rosalind1.JPG](attachment:Rosalind1.JPG)

# %% [markdown]
# 2. ![Rosalind2.JPG](attachment:Rosalind2.JPG)

# %% [markdown]
# 3. ![Rosalind3.JPG](attachment:Rosalind3.JPG)

# %% [markdown]
# Ejercicios CodingBat

# %%
#Warmup-1 
def sleep_in(weekday, vacation):
  if vacation==True or weekday==False:
    return True
  else:
    return False

# %%
#Logic-1
def date_fashion(you, date):
  if you<=2 or date<=2: 
    return 0
  elif you>=8 or date>=8:
    return 2
  else:
    return 1

# %% [markdown]
# List-1
# ![List1.JPG](attachment:List1.JPG)

# %% [markdown]
# ![List2.JPG](attachment:List2.JPG)

# %% [markdown]
# String-1
# ![LOLO.JPG](attachment:LOLO.JPG)

# %% [markdown]
# ![OUT.JPG](attachment:OUT.JPG)
