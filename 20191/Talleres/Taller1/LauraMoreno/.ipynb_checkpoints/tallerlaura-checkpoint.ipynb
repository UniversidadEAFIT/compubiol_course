# %% [markdown]
# Taller 1
#
# Laura Cristina Moreno Jiménez
#
# Primer y segundo punto
#
# ![1.png](attachment:1.png)
#
# Tercer punto
#
# ![list1.png](attachment:list1.png)
# ![string1.png](attachment:string1.png)
#
# Cuarto punto
#
# ![4a.png](attachment:4a.png)
# ![4b.png](attachment:4b.png)
# ![4c.png](attachment:4c.png)
#
#
# Quinto punto
#
# ![5a.png](attachment:5a.png)
# ![5b.png](attachment:5b.png)
