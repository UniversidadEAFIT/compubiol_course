# %% [markdown]
# Taller 1
# 1,2,3. se crea la cuenta en datacamp y se realiza el curso hasta donde es permitido,antes de generar un cobro
# ##Recuerda cambiar a Markdown las celdas cuando quieres incluir texto

# %% [markdown]
# ![Captura.png](attachment:Captura.png)

# %% [markdown]
# 4. hacer 3 ejercicios en Rosalind

# %% [markdown]
# ![primerorosalind.PNG](attachment:primerorosalind.PNG)

# %% [markdown]
# ![segundo.PNG](attachment:segundo.PNG)

# %% [markdown]
# ![tercer.PNG](attachment:tercer.PNG)

# %% [markdown]
# 5.Realizar un ejercicio de cada nivel de "Warmup-1 y Logic-1"
# además se incluyen otros dos ejercicios debido a que el curso de Python no se puede hacer completo

# %% [markdown]
# ![war.png](attachment:war.png)

# %% [markdown]
# ![logic.PNG](attachment:logic.PNG)

# %% [markdown]
# ![stri.PNG](attachment:stri.PNG)

# %% [markdown]
# ![Captura3.PNG](attachment:Captura3.PNG)

# %% [markdown]
# Enviar el notebook de jupyter completo a la carpeta del github del curso https://github.com/UniversidadEAFIT/compubiol_course/tree/master/20191/Talleres/Taller1 o en su defecto envíarlo al correo de interactiva.
